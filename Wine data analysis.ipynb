# %% [markdown]
# # [Wine Quality Data Set from UCI Machine Learning Lab](https://archive.ics.uci.edu/ml/datasets/Wine+Quality)

# %% [markdown]
# # 1- Gathering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
rdf = pd.read_csv("data/winequality-red.csv", sep=";")
rdf.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wdf = pd.read_csv("data/winequality-white.csv", sep=";")
wdf.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# # 2- Accessing

# %% [markdown]
# ## a.number of samples in each dataset:

# %%
rdf.shape[0]
# Out:
# 1599

# %%
wdf.shape[0]
# Out:
# 4898

# %% [markdown]
# ## b.number of columns in each dataset:

# %%
rdf.shape[1]
# Out:
# 12

# %%
wdf.shape[1]
# Out:
# 12

# %% [markdown]
# ## c. features with missing values

# %%
rdf.isnull().sum().sum()
# Out:
# 0

# %%
wdf.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## d. duplicate rows

# %%
rdf.duplicated().sum()
# Out:
# 240

# %%
wdf.duplicated().sum()
# Out:
# 937

# %% [markdown]
# ## e. number of unique values for quality in each dataset

# %%
rdf.quality.nunique()
# Out:
# 6

# %%
wdf.quality.nunique()
# Out:
# 7

# %% [markdown]
# ## f. mean density of the each dataset

# %%
rdf.density.mean()
# Out:
# 0.9967466791744833

# %%
wdf.density.mean()
# Out:
# 0.9940273764801896

# %% [markdown]
# ## 3. Appending Data
# combine the red and white datasets to make your analysis more efficient.

# %% [markdown]
# ### create the color columns

# %%
rdf['color'] = np.repeat('red', rdf.shape[0])

rdf.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
wdf['color']  = np.repeat('white', wdf.shape[0])

wdf.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %% [markdown]
# ### Combine DataFrames with Append
# > using [Pandas' append](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.append.html)

# %%
wine_df = rdf.append(wdf)
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
wine_df.columns = [e.replace(' ', '_') for e in wine_df.columns]
wine_df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %% [markdown]
# ### Save Combined Dataset

# %%
wine_df.to_csv('edited_data/winequality_edited.csv', index=False)

# %% [markdown]
# # exploratory data analysis (EDA) with Visuals

# %% [markdown]
# Based on histograms of columns in this dataset, which of the following feature variables appear skewed to the right? Fixed Acidity, Total Sulfur Dioxide, pH, Alcohol

# %% [markdown]
# ### Histograms for Various Features

# %%
wine_df.hist(figsize=(15,15));

# %%
wine_df.fixed_acidity.hist();

# %%
wine_df.total_sulfur_dioxide.hist();

# %%
wine_df.pH.hist();

# %%
wine_df.alcohol.hist();

# %% [markdown]
# ### Scatterplots of Quality Against Various Features

# %% [markdown]
# Based on scatterplots of quality against different feature variables, which of the following is most likely to have a positive impact on quality? Volatile Acidity, Residual Sugar, pH, Alcohol

# %%
pd.plotting.scatter_matrix(wine_df, figsize=(15,15));

# %%
wine_df.plot(x="volatile_acidity", y="quality", kind="scatter");

# %%
wine_df.plot(x="residual_sugar", y="quality", kind="scatter");

# %%
wine_df.plot(x="pH", y="quality", kind="scatter");

# %%
wine_df.plot(x="alcohol", y="quality", kind="scatter");

# %% [markdown]
# ##  Drawing Conclusions

# %% [markdown]
# - Q1: Is a certain type of wine (red or white) associated with higher quality?
# - Q2: What level of acidity (pH value) receives the highest average rating?

# %% [markdown]
# ### Q1: Is a certain type of wine (red or white) associated with higher quality?

# %%
wine_df.groupby('color').quality.mean()
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %% [markdown]
# ###  Q2: What level of acidity (pH value) receives the highest average rating?

# %%
# View the min, 25%, 50%, 75%, max pH values with Pandas describe
wine_df.describe().pH[3:]
# Out:
# min    2.72
# 25%    3.11
# 50%    3.21
# 75%    3.32
# max    4.01
# Name: pH, dtype: float64

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = list(np.array(wine_df.describe().pH[3:]))
bin_edges
# Out:
# [2.72, 3.11, 3.21, 3.32, 4.01]

# %%
# Labels for the four acidity level groups
bin_names = ['high', 'mod_high', 'medium', 'low'] # Name each acidity level category
bin_names
# Out:
# ['high', 'mod_high', 'medium', 'low']

# %%
# Creates acidity_levels column
wine_df['acidity_levels'] = pd.cut(wine_df['pH'], bin_edges, labels=bin_names)

# Checks for successful creation of this column
wine_df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_levels
# 0      9.4        5   red            low
# ...

# %%
# Find the mean quality of each acidity level with groupby
wine_df.groupby('acidity_levels').mean().quality
# Out:
# acidity_levels
# high        5.783343
# mod_high    5.784540
# medium      5.850832
# low         5.859593
# Name: quality, dtype: float64

# %%
# Save changes 
wine_df.to_csv('edited_data/winequality_edited.csv', index=False)

# %% [markdown]
# ## Drawing Conclusions Using Query
# - Q1:  Do wines with higher alcoholic content receive better ratings?
# - Q2: Do sweeter wines (more residual sugar) receive better ratings?

# %% [markdown]
# ####  Q1: Do wines with higher alcoholic content receive better ratings?

# %%
# get the median amount of alcohol content
wine_df.alcohol.median()
# select samples with alcohol content less than the median
low_alcohol = wine_df.query('alcohol <= 10.3')

# select samples with alcohol content greater than or equal to the median
high_alcohol = wine_df.query('alcohol > 10.3')

# ensure these queries included each sample exactly once
num_samples = wine_df.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low alcohol and high alcohol groups
low_alcohol.quality.mean(), high_alcohol.quality.mean()
# Out:
# (5.484673748103186, 6.161773891317926)

# %% [markdown]
# ### Q2: Do sweeter wines (more residual sugar) receive better ratings?

# %%
# get the median amount of residual sugar
mrs = wine_df.residual_sugar.median()
mrs
# Out:
# 3.0

# %%
# select samples with residual sugar less than the median
low_sugar = wine_df.query('residual_sugar < 3')

# select samples with residual sugar greater than or equal to the median
high_sugar = wine_df.query('residual_sugar >= 3')

# ensure these queries included each sample exactly once
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low sugar and high sugar groups
low_sugar.quality.mean(), high_sugar.quality.mean()
# Out:
# (5.808800743724822, 5.82782874617737)

# %% [markdown]
# ## Type & Quality Plot

# %%
8*2.5
104/(86400*200)
# Out:
# 6.0185185185185185e-06
